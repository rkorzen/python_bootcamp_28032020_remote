# %%
import numpy as np

# %% [markdown]
# # Indeksowanie, wycinanie, iterowanie - Indexing, Slicing and Iterating

# %% [markdown]
# ### Stwórz liste sześcianów liczb od 0 do 9

# %%
szesciany = np.arange(10) ** 3
szesciany
# Out:
# array([  0,   1,   8,  27,  64, 125, 216, 343, 512, 729])

# %% [markdown]
# ### wybierz z listy zaznaczone elementy
#
# [ 0, 1, **8, 27, 64**, 125, 216, 343, 512, 729]

# %%
szesciany[2:5]
# Out:
# array([ 8, 27, 64])

# %% [markdown]
# [<b>0</b>, 1, <b>8</b>, 27, <b>64</b>, 125, 216, 343, 512, 729]

# %%
szesciany[:5:2]
# Out:
# array([ 0,  8, 64])

# %% [markdown]
# ### przekształć by otrzymać wynik
#
# [-1000, 1,  -1000, 27, -1000,   125,   216,   343,   512, 729]

# %%
szesciany[:5:2] = -1000
szesciany
# Out:
# array([-1000,     1, -1000,    27, -1000,   125,   216,   343,   512,
#          729])

# %% [markdown]
# ### Odwróć listę

# %%
szesciany[::-1]
# Out:
# array([  729,   512,   343,   216,   125, -1000,    27, -1000,     1,
#        -1000])

# %% [markdown]
# ### Sprawdź typ

# %% [markdown]
# ### W pętli for wyprintuj dla każdego elementu pierwiastek sześcienny z elementy

# %% [markdown]
# ### Stwórz macierz 10x10 z kwadratami liczb od 1 do 100

# %% [markdown]
# ### Stwórz macierz 5x5 gdzie na krawędziach będą 0 a w środku 1

# %% [markdown]
# ### Stwórz tabliczkę mnożenia liczb od 0 do 9 w postaci dwuwymiarowej macierzy

# %%
# !ls
# Out:
# bmp.py
# ex_1.py
# ex_2.py
# images
# intro_numpy.ipynb
# Podstawy Pythona 04 - Exceptions - 03.12.2016.ipynb
# Podstawy Pythona 04 - NumPy Basics - 03.12.2016.ipynb
# Untitled.ipynb

# %% [markdown]
# ## Zad 2  Przekształć wczytane obrazki w opisany sposób

# %%
# !pip install opencv-python
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import matplotlib.image as mpimg
im1 = mpimg.imread('images/monkey.png')

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/f6/cd/0642144e580aa2fda0dc70276a432a48542351a620d26f0d1e3c5169ff49/opencv_python-4.2.0.34-cp38-cp38-macosx_10_9_x86_64.whl (49.1MB)
#      |████████████████████████████████| 49.1MB 12.3MB/s eta 0:00:01    |██████████                      | 15.3MB 1.0MB/s eta 0:00:34     |█████████████                   | 19.8MB 1.0MB/s eta 0:00:30     |██████████████▎                 | 21.9MB 1.0MB/s eta 0:00:27     |████████████████▏               | 24.8MB 11.7MB/s eta 0:00:03     |████████████████████▋           | 31.6MB 11.7MB/s eta 0:00:02     |██████████████████████████▉     | 41.1MB 14.7MB/s eta 0:00:01     |█████████████████████████████   | 44.6MB 14.7MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /Users/rkorzen/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from opencv-python) (1.18.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.2.0.34
# WARNING: You are using pip version 19.2.3, however version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import cv2
im2 = cv2.imread("images/index.jpeg")

# %%
im1.shape
# Out:
# (177, 284, 4)

# %%
im2.shape
# Out:
# (177, 284, 3)

# %%
im1.max()
# Out:
# 1.0

# %%
plt.imshow(im1)

# %%
plt.imshow(im2)

# %%
# !pwd
# Out:
# /Users/rkorzen/PycharmProjects/python_bootcamp_28032020_remote/08_numpy_pandas

# %% [markdown]
# ### stwórz wycinek -  spróbuj wybrać twarz

# %%
plt.imshow(im1[20:160, 80:190,:])

# %% [markdown]
# ### wybierz jeden kolor

# %%
im3 = im1.copy()
im3[:,:,1] = 0
im3[:,:,2] = 0

plt.imshow(im3)

# %%
red, green, blue = True, False, True

plt.imshow(im1 * np.array([red, green, blue, True]))

# %% [markdown]
# ### Obrót o wskazaną liczbę stopni
#
# wykorzystaj ndimage.rotate ze scipy

# %%
#!pip install scipy

# %%
from scipy.ndimage import rotate

plt.imshow(rotate(im1, 70))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
l = np.random.rand(100, 100)
rim = np.random.rand(100, 100, 3)

rim[:, :, 0] = l
rim[:, :, 1] = l
rim[:, :, 2] = l

# %%
plt.imshow(rim)

# %% [markdown]
# ### Czarno biały filtr

# %%
data = im2.copy()

sum_array = data.sum(axis=2, keepdims=True)
sum_array = sum_array / sum_array.max()

d = np.ones(3) * sum_array 
plt.imshow(d)

# %% [markdown]
# ### Rozmazanie

# %% [markdown]
# wykorzystaj `ndimage.gaussian_filter`

# %%
from scipy.ndimage import gaussian_filter

plt.imshow(gaussian_filter(im1, 0.9))

# %% [markdown]
# Wyślij mi to proszę na adres: korzeniewski@gmail.com, w tytule wpisz "Ćwiczenia z NumPy"

# %%
# !ls
# Out:
# files_pandas_21_01_2017       numpy_bootcamp_zadania.ipynb
# images                        pandas_cwiczenia.ipynb
# matplotlib_wprowadzenie.ipynb sprawdzian.ipynb

# %%
import os
os.listdir()
# Out:
# ['pandas_cwiczenia.ipynb',
#  'images',
#  'numpy_bootcamp_zadania.ipynb',
#  'sprawdzian.ipynb',
#  '.ipynb_checkpoints',
#  'matplotlib_wprowadzenie.ipynb',
#  'files_pandas_21_01_2017']
